# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

import geopandas as gpd
import pandas as pd
import polars as pl

from utils import flags_to_label_df, flags_to_sample_df

# %%
# server_root = "/mnt/share/FER"
server_root = "//digs110/FER"

# %% [markdown]
# # Homogenize Sample Data
#
# following columns will be compiled
#
# Two files:
#
# samples.geoparquet (? file format)
#
# - Unique Sample ID (int)
# - Original Sample ID (int)
# - Interpreter (str)
# - Source (str)
# - S2 Tile (str)
# - Cluster (Polygon ID, storm event) (str)
# - Cluster Description (str)
# - Comment (str)
# - Confidence (categorical)
# - Point (geometry)
#
# labels.pq
#
# - Timestamp (datetime)
# - original label (str)
# - Label (categorical)

# %%
samples_schema = gpd.GeoDataFrame(
    {
        "sample_id": pd.Series(dtype="uint16[pyarrow]"),
        "original_sample_id": pd.Series(dtype="int64[pyarrow]"),
        "interpreter": pd.Series(dtype="string[pyarrow]"),
        "dataset": pd.Series(dtype="string[pyarrow]"),
        "source": pd.Series(dtype="string[pyarrow]"),
        "source_description": pd.Series(dtype="string[pyarrow]"),
        "s2_tile": pd.Series(dtype="string[pyarrow]"),
        "cluster_id": pd.Series(dtype="string[pyarrow]"),
        "cluster_description": pd.Series(dtype="string[pyarrow]"),
        "comment": pd.Series(dtype="string[pyarrow]"),
        "confidence": pd.Series(
            dtype="string[pyarrow]"
        ),  # PyArrow doesn't yet support 'categorical' as a dtype
        "geometry": gpd.GeoSeries(crs="EPSG:4326"),
    },
    geometry="geometry",
)

# %%
labels_schema = pd.DataFrame(
    {
        "sample_id": pd.Series(dtype="uint16[pyarrow]"),
        "original_sample_id": pd.Series(dtype="int64[pyarrow]"),
        "dataset": pd.Series(dtype="string[pyarrow]"),
        "label": pd.Series(dtype="uint16[pyarrow]"),
        "original_label": pd.Series(dtype="string[pyarrow]"),
        "start": pd.Series(dtype="timestamp[s, tz=UTC][pyarrow]"),
        "end": pd.Series(dtype="timestamp[s, tz=UTC][pyarrow]"),
    }
)

# %% [markdown]
# # Label mapping
#
# The labels can be mapped roughly based on the categorization of ICP forest data. Going from coarse to fine categorization.
# If more e0act reasons aren't known, the coarser category can be set.
#
# <pre>
# 100 - Alive Vegetation
#     110 - Mature Forest
#     120 - Revegetation
#         121 - With Trees (after clear cut)
#         122 - Canopy closing (after thinning/defoliation)
#         123 - Without Trees (shrubs and grasses, no reforestation visible)
#
# 200 - Disturbed
#     210 - Planned
#         211 - Clear Cut
#         212 - Thinning
#         213 - Forestry Mulching (Non Forest Vegetation Removal)
#     220 - Salvage
#         221 - After Biotic Disturbance
#         222 - After Abiotic Disturbance
#     230 - Biotic
#         231 - Bark Beetle (with decline)
#         232 - Gypsy Moth (temporary)
#     240 - Abiotic
#         241 - Drought
#         242 - Wildfire
#         243 - Wind
#         244 - Avalanche
#         245 - Flood
# </pre>

# %% [markdown]
# ## Evoland + FNEWs

# %%
# evoland
evoland = Path(
    server_root
    + "/EvoLand/WP2_6_CFM/Referenzdaten/Database/PointMultitemp/evoland_ref_points_mt.shp"
)
evoland_multitemp = gpd.read_file(evoland)

# %%
# Drop duplicates since the geometry and sample ID are likely repeated
samples_df = evoland_multitemp.drop_duplicates(
    "id"
).copy()  # .copy() to avoid SettingWithCopyWarning


def combine_comments(row):
    parts = [row["comment1"], row["comment2"], row["comment3"]]
    # Filter out None / NaN / empty
    parts = [str(p) for p in parts if pd.notna(p) and str(p).strip()]
    return " ".join(parts) if parts else ""

# %%
samples_df["source"] = samples_df["site"].replace(
    {"Spain": "EFFIS", "Germany": "Regional Forestry Departments", "Sweden": "EFFIS"}
)
samples_df["source_description"] = samples_df["site"].replace(
    {
        "Spain": "Evoland Project, EFFIS Source of Wildfire Polygons, manual interpretation based on S2 timeseries",
        "Germany": "FNews Project, German Forestry Departmetns Source of Disturbance Types, manual interpretation based on S2 timeseries",
        "Sweden": "Evoland Project, EFFIS Source of Wildfire Polygons, manual interpretation based on S2 timeseries",
    }
)
samples_df["comment"] = samples_df.apply(combine_comments, axis=1)

# %%
# get new labels/confidence/labeller from flags
flag_paths = list(Path("../data/evoland_flags_reinterpreted").glob("*.json"))
raw_evo_labels = flags_to_label_df(flag_paths)
raw_evo_samples = flags_to_sample_df(flag_paths)

# %%
subset_samples = samples_df[
    ["id", "poly_id", "tile", "source", "source_description", "geometry"]
]

# %%
filtered_raw_samples = raw_evo_samples.filter(
    pl.col.confidence.is_in(["high", "medium"]),
    # If interpreter is still evo, the sample has not been reinterpreted
    # there are a few sample points which are exact duplicates for which this is the case
    pl.col.interpreter.ne(pl.lit("evo")),
).with_columns(
    # remove the comment, if it is the same as in the original evoland table
    pl.col.original_sample_id.cast(pl.Int64),
    comment=(
        pl.when(pl.col.comment.is_in(samples_df["comment"].drop_duplicates().to_list()))
        .then(pl.lit(""))
        .otherwise(pl.col.comment)
    ),
)
filtered_raw_samples
# Out:
# shape: (913, 4)
# ┌────────────┬─────────────────────────────────┬─────────────┬────────────────────┐
# │ confidence ┆ comment                         ┆ interpreter ┆ original_sample_id │
# │ ---        ┆ ---                             ┆ ---         ┆ ---                │
# │ str        ┆ str                             ┆ str         ┆ i64                │
# ╞════════════╪═════════════════════════════════╪═════════════╪════════════════════╡
# │ high       ┆ border, thinning, then clear c… ┆ vij         ┆ 0                  │
# │ medium     ┆ unclear progression, edge       ┆ vij         ┆ 1                  │
# │ high       ┆ very low tcd, new plantation    ┆ vij         ┆ 10                 │
# │ high       ┆                                 ┆ vij         ┆ 100                │
# │ high       ┆                                 ┆ vij         ┆ 101                │
# │ …          ┆ …                               ┆ …           ┆ …                  │
# │ high       ┆                                 ┆ vij         ┆ 992                │
# │ high       ┆                                 ┆ vij         ┆ 993                │
# │ high       ┆                                 ┆ vij         ┆ 995                │
# │ high       ┆                                 ┆ vij         ┆ 996                │
# │ high       ┆                                 ┆ vij         ┆ 997                │
# └────────────┴─────────────────────────────────┴─────────────┴────────────────────┘

# %%
evo_samples_together = filtered_raw_samples.to_pandas().merge(
    subset_samples, left_on="original_sample_id", right_on="id"
)
evo_samples_together
# Out:
#     confidence                           comment interpreter  \
# 0         high  border, thinning, then clear cut         vij
# 1       medium         unclear progression, edge         vij
# 2         high      very low tcd, new plantation         vij
# 3         high                                           vij
# 4         high                                           vij
# ..         ...                               ...         ...
# 908       high                                           vij
# 909       high                                           vij
# 910       high                                           vij
# 911       high                                           vij
# 912       high                                           vij
#
#      original_sample_id   id  poly_id   tile                         source  \
# 0                     0    0      0.0  30SUF                          EFFIS
# 1                     1    1      1.0  30SUF                          EFFIS
# 2                    10   10     11.0  30SUF                          EFFIS
# 3                   100  100     38.0  30SUF                          EFFIS
# 4                   101  101     38.0  30SUF                          EFFIS
# ..                  ...  ...      ...    ...                            ...
# 908                 992  992    331.0  32UNC  Regional Forestry Departments
# 909                 993  993    325.0  32UNC  Regional Forestry Departments
# 910                 995  995    391.0  32UNC  Regional Forestry Departments
# 911                 996  996    325.0  32UNC  Regional Forestry Departments
# 912                 997  997    364.0  32UNC  Regional Forestry Departments
#
#                                     source_description  \
# 0    Evoland Project, EFFIS Source of Wildfire Poly...
# 1    Evoland Project, EFFIS Source of Wildfire Poly...
# 2    Evoland Project, EFFIS Source of Wildfire Poly...
# 3    Evoland Project, EFFIS Source of Wildfire Poly...
# 4    Evoland Project, EFFIS Source of Wildfire Poly...
# ..                                                 ...
# 908  FNews Project, German Forestry Departmetns Sou...
# 909  FNews Project, German Forestry Departmetns Sou...
# 910  FNews Project, German Forestry Departmetns Sou...
# 911  FNews Project, German Forestry Departmetns Sou...
# 912  FNews Project, German Forestry Departmetns Sou...
#
#                       geometry
# 0    POINT (-4.12212 36.74179)
# 1    POINT (-4.12161 36.74231)
# 2    POINT (-4.13315 36.76793)
# 3    POINT (-5.14862 36.51116)
# 4    POINT (-5.15389 36.50781)
# ..                         ...
# 908  POINT (10.14152 51.73675)
# 909   POINT (9.94794 51.79978)
# 910  POINT (10.24565 51.62535)
# 911   POINT (9.94913 51.80094)
# 912   POINT (9.77607 51.77389)
#
# [913 rows x 10 columns]

# %%
# Create the new GeoDataFrame for samples
# Initialize with None/default values where appropriate
samples_evo = (
    gpd.GeoDataFrame(
        {
            "original_sample_id": evo_samples_together["id"],
            "interpreter": "vij",
            "source": evo_samples_together["source"],
            "source_description": evo_samples_together["source_description"],
            "dataset": "Evoland",
            "s2_tile": evo_samples_together["tile"],
            "cluster_id": evo_samples_together["poly_id"],
            "cluster_description": "Damage polygons",
            "comment": evo_samples_together["comment"],
            "confidence": evo_samples_together["confidence"],
            "geometry": evo_samples_together["geometry"],
        },
        crs=samples_df.crs,  # Retain the original Coordinate Reference System
    )
    .astype(samples_schema.dtypes.drop(["sample_id", "geometry"]))
    .sort_values("original_sample_id")
)

# %%
samples_evo
# Out:
#      original_sample_id interpreter                         source  \
# 0                     0         vij                          EFFIS
# 1                     1         vij                          EFFIS
# 299                   2         vij                          EFFIS
# 396                   3         vij                          EFFIS
# 474                   4         vij                          EFFIS
# ..                  ...         ...                            ...
# 215                1263         vij  Regional Forestry Departments
# 216                1264         vij  Regional Forestry Departments
# 217                1265         vij  Regional Forestry Departments
# 218                1266         vij  Regional Forestry Departments
# 219                1267         vij  Regional Forestry Departments
#
#                                     source_description  dataset s2_tile  \
# 0    Evoland Project, EFFIS Source of Wildfire Poly...  Evoland   30SUF
# 1    Evoland Project, EFFIS Source of Wildfire Poly...  Evoland   30SUF
# 299  Evoland Project, EFFIS Source of Wildfire Poly...  Evoland   30SUF
# 396  Evoland Project, EFFIS Source of Wildfire Poly...  Evoland   30SUF
# 474  Evoland Project, EFFIS Source of Wildfire Poly...  Evoland   30SUF
# ..                                                 ...      ...     ...
# 215  FNews Project, German Forestry Departmetns Sou...  Evoland   33UVS
# 216  FNews Project, German Forestry Departmetns Sou...  Evoland   33UVS
# 217  FNews Project, German Forestry Departmetns Sou...  Evoland   33UVS
# 218  FNews Project, German Forestry Departmetns Sou...  Evoland   33UVS
# 219  FNews Project, German Forestry Departmetns Sou...  Evoland   33UVS
#
#     cluster_id cluster_description                           comment  \
# 0          0.0     Damage polygons  border, thinning, then clear cut
# 1          1.0     Damage polygons         unclear progression, edge
# 299        2.0     Damage polygons                        plantation
# 396        3.0     Damage polygons                        plantation
# 474        5.0     Damage polygons                         clear cut
# ..         ...                 ...                               ...
# 215      421.0     Damage polygons
# 216      420.0     Damage polygons
# 217       <NA>     Damage polygons
# 218      419.0     Damage polygons
# 219      440.0     Damage polygons
#
#     confidence                   geometry
# 0         high  POINT (-4.12212 36.74179)
# 1       medium  POINT (-4.12161 36.74231)
# 299       high   POINT (-4.1192 36.74203)
# 396       high  POINT (-4.12845 36.75831)
# 474       high  POINT (-4.12816 36.75908)
# ..         ...                        ...
# 215       high  POINT (14.08833 50.99596)
# 216       high   POINT (14.10273 51.0011)
# 217       high  POINT (14.11205 51.00166)
# 218       high  POINT (14.10425 51.00364)
# 219       high  POINT (14.11987 51.02323)
#
# [913 rows x 11 columns]

# %%
hrvpp_label_mapping = {
    "0": 110,  # Stable → Mature Forest
    "1": 231,  # Biotic disturbance / bark-beetle → Bark Beetle (with decline)
    "2": 230,  # Biotic disturbance / other → Biotic (unspecific)
    "3": 120,  # Growth → Revegetation (with trees / canopy closing)
    "4": 123,  # Revegetation → Without Trees (shrubs and grasses, no reforestation)
    "b": 123,  # Stable / non-forest → Without Trees (assumes non-forest like grassland/shrubland)
    # Event flags
    "5": 211,  # Harvest / clear-cut → Clear Cut
    "6": 212,  # Harvest / thinning or selective logging → Thinning
    "7": 243,  # Abiotic disturbance / windthrow → Wind
    "8": 242,  # Abiotic disturbance / wildfire → Wildfire
    "9": 240,  # Abiotic disturbance / other → Abiotic (unspecific)
    "a": 220,  # Harvest / salvage logging → After Natural Disturbance (Needs to be split into after abiotic and biotic)
    "c": 213,  # Vegetation removal → Forestry Mulching (Non Forest Vegetation Removal)
    "d": 999,  # L3A artifact → No match in primary classes (metadata/quality issue)
    "e": 200,  # Unknown disturbance
}

# %%
# bring them to start end format as done for the hrvpp calibration set
labels_evo = (
    raw_evo_labels.with_columns(
        pl.col.original_label.replace_strict(hrvpp_label_mapping).alias("label"),
        dataset=pl.lit("Evoland"),
    )
    .to_pandas()
    .astype(labels_schema.dtypes.drop("sample_id"))
)
labels_evo
# Out:
#      original_label                      start                        end  \
# 0                 0  2016-11-10 00:00:00+00:00  2022-03-09 00:00:00+00:00
# 1                 6  2022-04-08 00:00:00+00:00  2022-04-08 23:59:59+00:00
# 2                 5  2024-04-02 00:00:00+00:00  2024-04-02 23:59:59+00:00
# 3                 0  2016-11-10 00:00:00+00:00  2023-05-03 00:00:00+00:00
# 4                 5  2023-06-22 00:00:00+00:00  2023-06-22 23:59:59+00:00
# ...             ...                        ...                        ...
# 3059              4  2021-05-21 00:00:00+00:00  2024-12-01 00:00:00+00:00
# 3060              0  2015-08-06 00:00:00+00:00  2019-04-25 00:00:00+00:00
# 3061              1  2019-10-07 00:00:00+00:00  2020-04-21 00:00:00+00:00
# 3062              a  2020-04-24 00:00:00+00:00  2020-04-24 23:59:59+00:00
# 3063              4  2020-07-13 00:00:00+00:00  2024-12-01 00:00:00+00:00
#
#       original_sample_id  label  dataset
# 0                      0    110  Evoland
# 1                      0    212  Evoland
# 2                      0    211  Evoland
# 3                      1    110  Evoland
# 4                      1    211  Evoland
# ...                  ...    ...      ...
# 3059                 996    123  Evoland
# 3060                 997    110  Evoland
# 3061                 997    231  Evoland
# 3062                 997    220  Evoland
# 3063                 997    123  Evoland
#
# [3064 rows x 6 columns]

# %% [markdown]
# ## HRVPP Calibration

# %%
flag_paths_hrvpp = list(
    Path(
        r"\\digs110\FER\HR-VPP2\Subversion\InterpretationVersioned\stage1\Flags_L3A_json"
    ).glob("*.json")
)
raw_hrvpp_labels = flags_to_label_df(flag_paths_hrvpp)
raw_hrvpp_samples = flags_to_sample_df(flag_paths_hrvpp)
# Out:
# Missing Segment
# 0058
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2021-11-25 00:00:00.000000": "c",
#         "2024-12-31 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "",
#     "interpreter": "pum"
# }
# Missing Segment
# 0083
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2017-02-14 00:00:00.000000": "c",
#         "2024-12-26 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "",
#     "interpreter": "pum"
# }
# Missing Segment
# 0098
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2020-03-10 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "very low TCD",
#     "interpreter": "pum"
# }
# Missing Segment
# 0114
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2022-08-27 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "soil management Aug 2022",
#     "interpreter": "pum"
# }
# Missing Segment
# 0184
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2019-06-09 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "low TCD, removal of vegetation between trees",
#     "interpreter": "pum"
# }
# Missing Segment
# 0192
# {
#     "flags": {
#         "2016-01-11 00:00:00.000000": "0",
#         "2020-03-07 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "other activity NW of point",
#     "interpreter": "pum"
# }
# Missing Segment
# 0200
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2019-04-12 00:00:00.000000": "0",
#         "2019-04-27 00:00:00.000000": "6",
#         "2019-04-30 00:00:00.000000": "0",
#         "2020-02-21 00:00:00.000000": "c",
#         "2022-05-26 00:00:00.000000": "c",
#         "2023-04-01 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "removal of trees 2019 confirmed by VHR, however pixel is mixed (almost no signal response)",
#     "interpreter": "pum"
# }
# Missing Segment
# 0209
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2019-01-02 00:00:00.000000": "c",
#         "2024-12-31 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "",
#     "interpreter": "pum"
# }
# Missing Segment
# 0218
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2018-02-24 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "low TCD",
#     "interpreter": "pum"
# }
# Missing Segment
# 0229
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2019-01-25 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "",
#     "interpreter": "pum"
# }
# Missing Segment
# 0230
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2019-04-22 00:00:00.000000": "c",
#         "2024-12-31 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "low TCD",
#     "interpreter": "pum"
# }
# Missing Segment
# 0231
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2016-05-20 00:00:00.000000": "c",
#         "2019-04-10 00:00:00.000000": "c",
#         "2024-05-08 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "very low TCD, multiple vegetation removals",
#     "interpreter": "pum"
# }
# Missing Segment
# 0236
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2019-05-25 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "",
#     "interpreter": "pum"
# }
# Missing Segment
# 0240
# {
#     "flags": {
#         "2016-03-08 00:00:00.000000": "0",
#         "2019-03-13 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "low TCD",
#     "interpreter": "pum"
# }
# Missing Segment
# 0247
# {
#     "flags": {
#         "2016-02-07 00:00:00.000000": "0",
#         "2017-03-01 00:00:00.000000": "d",
#         "2018-12-06 00:00:00.000000": "c",
#         "2024-12-31 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "",
#     "interpreter": "pum"
# }
# Missing Segment
# 0251
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2020-07-05 00:00:00.000000": "c",
#         "2024-12-31 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "low TCD, looks more like a meadow with trees",
#     "interpreter": "pum"
# }
# Missing Segment
# 0261
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2021-05-29 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "soil management in 2021",
#     "interpreter": "pum"
# }
# Missing Segment
# 0263
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2021-04-19 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "low TCD, removal of ground vegetation with high signal response, but trees seem unaffected",
#     "interpreter": "pum"
# }
# Missing Segment
# 0759
# {
#     "flags": {
#         "2016-05-04 00:00:00.000000": "0",
#         "2022-03-24 00:00:00.000000": "0",
#         "2025-01-01 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "at border, not sure if the deviation in 2022 affects the trees",
#     "interpreter": "pum"
# }
# Missing Segment
# 0843
# {
#     "flags": {
#         "2016-01-12 00:00:00.000000": "0",
#         "2020-07-07 00:00:00.000000": "c",
#         "2022-09-20 00:00:00.000000": "0",
#         "2022-09-22 00:00:00.000000": "5",
#         "2023-07-01 00:00:00.000000": "4",
#         "2025-01-01 00:00:00.000000": "4"
#     },
#     "confidence": "low",
#     "comment": "border pixel with complex mixed condition, should not be used",
#     "interpreter": "pum"
# }
# Missing Segment
# 0871
# {
#     "flags": {
#         "2016-03-05 00:00:00.000000": "b",
#         "2021-07-17 00:00:00.000000": "c",
#         "2024-08-25 00:00:00.000000": "c",
#         "2024-12-23 00:00:00.000000": "b"
#     },
#     "confidence": "medium",
#     "comment": "no trees",
#     "interpreter": "pum"
# }
# Missing Segment
# 1980
# {
#     "flags": {
#         "2016-01-01 00:00:00.000000": "0",
#         "2016-03-21 00:00:00.000000": "0",
#         "2024-12-19 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "border, adjacent windthrow in summer 2020 supported by VHR image",
#     "interpreter": "pum"
# }

# %%
flag_paths_hrvpp = list(
    Path(
        r"\\digs110\FER\HR-VPP2\Subversion\InterpretationVersioned\stage1\Flags_L3A_json"
    ).glob("*.json")
)
raw_hrvpp_labels = flags_to_label_df(flag_paths_hrvpp)
raw_hrvpp_samples = flags_to_sample_df(flag_paths_hrvpp)
# Out:
# Missing Segment
# 0058
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2021-11-25 00:00:00.000000": "c",
#         "2024-12-31 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "",
#     "interpreter": "pum"
# }
# Missing Segment
# 0083
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2017-02-14 00:00:00.000000": "c",
#         "2024-12-26 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "",
#     "interpreter": "pum"
# }
# Missing Segment
# 0098
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2020-03-10 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "very low TCD",
#     "interpreter": "pum"
# }
# Missing Segment
# 0114
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2022-08-27 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "soil management Aug 2022",
#     "interpreter": "pum"
# }
# Missing Segment
# 0184
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2019-06-09 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "low TCD, removal of vegetation between trees",
#     "interpreter": "pum"
# }
# Missing Segment
# 0192
# {
#     "flags": {
#         "2016-01-11 00:00:00.000000": "0",
#         "2020-03-07 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "other activity NW of point",
#     "interpreter": "pum"
# }
# Missing Segment
# 0200
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2019-04-12 00:00:00.000000": "0",
#         "2019-04-27 00:00:00.000000": "6",
#         "2019-04-30 00:00:00.000000": "0",
#         "2020-02-21 00:00:00.000000": "c",
#         "2022-05-26 00:00:00.000000": "c",
#         "2023-04-01 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "removal of trees 2019 confirmed by VHR, however pixel is mixed (almost no signal response)",
#     "interpreter": "pum"
# }
# Missing Segment
# 0209
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2019-01-02 00:00:00.000000": "c",
#         "2024-12-31 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "",
#     "interpreter": "pum"
# }
# Missing Segment
# 0218
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2018-02-24 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "low TCD",
#     "interpreter": "pum"
# }
# Missing Segment
# 0229
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2019-01-25 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "",
#     "interpreter": "pum"
# }
# Missing Segment
# 0230
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2019-04-22 00:00:00.000000": "c",
#         "2024-12-31 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "low TCD",
#     "interpreter": "pum"
# }
# Missing Segment
# 0231
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2016-05-20 00:00:00.000000": "c",
#         "2019-04-10 00:00:00.000000": "c",
#         "2024-05-08 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "very low TCD, multiple vegetation removals",
#     "interpreter": "pum"
# }
# Missing Segment
# 0236
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2019-05-25 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "",
#     "interpreter": "pum"
# }
# Missing Segment
# 0240
# {
#     "flags": {
#         "2016-03-08 00:00:00.000000": "0",
#         "2019-03-13 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "low TCD",
#     "interpreter": "pum"
# }
# Missing Segment
# 0247
# {
#     "flags": {
#         "2016-02-07 00:00:00.000000": "0",
#         "2017-03-01 00:00:00.000000": "d",
#         "2018-12-06 00:00:00.000000": "c",
#         "2024-12-31 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "",
#     "interpreter": "pum"
# }
# Missing Segment
# 0251
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2020-07-05 00:00:00.000000": "c",
#         "2024-12-31 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "low TCD, looks more like a meadow with trees",
#     "interpreter": "pum"
# }
# Missing Segment
# 0261
# {
#     "flags": {
#         "2016-03-11 00:00:00.000000": "0",
#         "2021-05-29 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "high",
#     "comment": "soil management in 2021",
#     "interpreter": "pum"
# }
# Missing Segment
# 0263
# {
#     "flags": {
#         "2016-02-17 00:00:00.000000": "0",
#         "2021-04-19 00:00:00.000000": "c",
#         "2024-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "low TCD, removal of ground vegetation with high signal response, but trees seem unaffected",
#     "interpreter": "pum"
# }
# Missing Segment
# 0759
# {
#     "flags": {
#         "2016-05-04 00:00:00.000000": "0",
#         "2022-03-24 00:00:00.000000": "0",
#         "2025-01-01 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "at border, not sure if the deviation in 2022 affects the trees",
#     "interpreter": "pum"
# }
# Missing Segment
# 0843
# {
#     "flags": {
#         "2016-01-12 00:00:00.000000": "0",
#         "2020-07-07 00:00:00.000000": "c",
#         "2022-09-20 00:00:00.000000": "0",
#         "2022-09-22 00:00:00.000000": "5",
#         "2023-07-01 00:00:00.000000": "4",
#         "2025-01-01 00:00:00.000000": "4"
#     },
#     "confidence": "low",
#     "comment": "border pixel with complex mixed condition, should not be used",
#     "interpreter": "pum"
# }
# Missing Segment
# 0871
# {
#     "flags": {
#         "2016-03-05 00:00:00.000000": "b",
#         "2021-07-17 00:00:00.000000": "c",
#         "2024-08-25 00:00:00.000000": "c",
#         "2024-12-23 00:00:00.000000": "b"
#     },
#     "confidence": "medium",
#     "comment": "no trees",
#     "interpreter": "pum"
# }
# Missing Segment
# 1980
# {
#     "flags": {
#         "2016-01-01 00:00:00.000000": "0",
#         "2016-03-21 00:00:00.000000": "0",
#         "2024-12-19 00:00:00.000000": "0"
#     },
#     "confidence": "medium",
#     "comment": "border, adjacent windthrow in summer 2020 supported by VHR image",
#     "interpreter": "pum"
# }

# %%
hrvpp_path = Path(
    server_root
    + "/HR-VPP2/Calibration/Interpretation/stage1/HR-VPP2_VDTC_calib_samples_stage1_merged.shp"
)
hrvpp = gpd.read_file(hrvpp_path)

# %%
together_hrvpp = (
    raw_hrvpp_samples.filter(pl.col.confidence.ne("low"))
    .to_pandas()
    .merge(
        hrvpp[["id", "id_str", "tile", "stratum", "geometry"]],
        left_on="original_sample_id",
        right_on="id_str",
    )
)
together_hrvpp
# Out:
#      confidence                   comment interpreter original_sample_id  \
# 0        medium             drought 2023?         pum               0001
# 1          high                   low TCD         vij               0002
# 2          high                                   pum               0003
# 3          high            road - low TCD         vij               0004
# 4          high                   low TCD         vij               0005
# ...         ...                       ...         ...                ...
# 2611       high                                   vij               2723
# 2612       high                                   vij               2724
# 2613     medium  widening of a power line         vij               2725
# 2614       high                                   pum               2726
# 2615       high                                   vij               2727
#
#         id id_str   tile  stratum                   geometry
# 0        1   0001  29SPC        1  POINT (-6.77759 38.22003)
# 1        2   0002  29SPC        1  POINT (-6.64978 38.46161)
# 2        3   0003  29SPC        1  POINT (-7.09658 38.57429)
# 3        4   0004  29SPC        1  POINT (-6.61063 38.36791)
# 4        5   0005  29SPC        1  POINT (-6.74202 38.24211)
# ...    ...    ...    ...      ...                        ...
# 2611  2723   2723  35VMJ     4042  POINT (25.51873 62.05893)
# 2612  2724   2724  35VMJ     4042   POINT (25.3021 62.20753)
# 2613  2725   2725  35VMJ     4042  POINT (26.07052 62.13655)
# 2614  2726   2726  35VMJ     4042  POINT (26.87233 61.92974)
# 2615  2727   2727  35VMJ     4042  POINT (26.35894 61.68179)
#
# [2616 rows x 9 columns]

# %%
# Create the new GeoDataFrame for samples
# Initialize with None/default values where appropriate
samples_hrvpp = (
    gpd.GeoDataFrame(
        {
            "original_sample_id": together_hrvpp["id"],
            "interpreter": together_hrvpp["interpreter"],
            "dataset": "HRVPP",
            "source": "Sentinel 2 Time-series",
            "source_description": "HR-VPP2 Project, manual interpretation based on S2 timeseries, ESRI wayback and ESA High Resolution Images",
            "s2_tile": together_hrvpp["tile"],
            "cluster_id": together_hrvpp["stratum"],
            "cluster_description": "Stratum of the sampling",
            "comment": together_hrvpp["comment"],
            "confidence": together_hrvpp["confidence"],
            "geometry": together_hrvpp["geometry"],
        },
        crs=hrvpp.crs,  # Retain the original Coordinate Reference System
    )
    .astype(samples_schema.dtypes.drop(["sample_id", "geometry"]))
    .sort_values("original_sample_id")
)

# %%
samples_hrvpp
# Out:
#       original_sample_id interpreter dataset                  source  \
# 0                      1         pum   HRVPP  Sentinel 2 Time-series
# 1                      2         vij   HRVPP  Sentinel 2 Time-series
# 2                      3         pum   HRVPP  Sentinel 2 Time-series
# 3                      4         vij   HRVPP  Sentinel 2 Time-series
# 4                      5         vij   HRVPP  Sentinel 2 Time-series
# ...                  ...         ...     ...                     ...
# 2611                2723         vij   HRVPP  Sentinel 2 Time-series
# 2612                2724         vij   HRVPP  Sentinel 2 Time-series
# 2613                2725         vij   HRVPP  Sentinel 2 Time-series
# 2614                2726         pum   HRVPP  Sentinel 2 Time-series
# 2615                2727         vij   HRVPP  Sentinel 2 Time-series
#
#                                      source_description s2_tile cluster_id  \
# 0     HR-VPP2 Project, manual interpretation based o...   29SPC          1
# 1     HR-VPP2 Project, manual interpretation based o...   29SPC          1
# 2     HR-VPP2 Project, manual interpretation based o...   29SPC          1
# 3     HR-VPP2 Project, manual interpretation based o...   29SPC          1
# 4     HR-VPP2 Project, manual interpretation based o...   29SPC          1
# ...                                                 ...     ...        ...
# 2611  HR-VPP2 Project, manual interpretation based o...   35VMJ       4042
# 2612  HR-VPP2 Project, manual interpretation based o...   35VMJ       4042
# 2613  HR-VPP2 Project, manual interpretation based o...   35VMJ       4042
# 2614  HR-VPP2 Project, manual interpretation based o...   35VMJ       4042
# 2615  HR-VPP2 Project, manual interpretation based o...   35VMJ       4042
#
#           cluster_description                   comment confidence  \
# 0     Stratum of the sampling             drought 2023?     medium
# 1     Stratum of the sampling                   low TCD       high
# 2     Stratum of the sampling                                 high
# 3     Stratum of the sampling            road - low TCD       high
# 4     Stratum of the sampling                   low TCD       high
# ...                       ...                       ...        ...
# 2611  Stratum of the sampling                                 high
# 2612  Stratum of the sampling                                 high
# 2613  Stratum of the sampling  widening of a power line     medium
# 2614  Stratum of the sampling                                 high
# 2615  Stratum of the sampling                                 high
#
#                        geometry
# 0     POINT (-6.77759 38.22003)
# 1     POINT (-6.64978 38.46161)
# 2     POINT (-7.09658 38.57429)
# 3     POINT (-6.61063 38.36791)
# 4     POINT (-6.74202 38.24211)
# ...                         ...
# 2611  POINT (25.51873 62.05893)
# 2612   POINT (25.3021 62.20753)
# 2613  POINT (26.07052 62.13655)
# 2614  POINT (26.87233 61.92974)
# 2615  POINT (26.35894 61.68179)
#
# [2616 rows x 11 columns]

# %%
# bring them to start end format as done for the hrvpp calibration set
labels_hrvpp = (
    raw_hrvpp_labels.with_columns(
        pl.col.original_label.replace_strict(hrvpp_label_mapping).alias("label"),
        dataset=pl.lit("HRVPP"),
    )
    .to_pandas()
    .astype(labels_schema.dtypes.drop("sample_id"))
)
labels_hrvpp
# Out:
#      original_label                      start                        end  \
# 0                 0  2016-03-01 00:00:00+00:00  2025-01-01 00:00:00+00:00
# 1                 0  2016-03-01 00:00:00+00:00  2025-01-01 00:00:00+00:00
# 2                 0  2016-03-01 00:00:00+00:00  2025-01-01 00:00:00+00:00
# 3                 b  2016-03-01 00:00:00+00:00  2025-01-01 00:00:00+00:00
# 4                 0  2016-03-01 00:00:00+00:00  2025-01-01 00:00:00+00:00
# ...             ...                        ...                        ...
# 4080              4  2023-07-16 00:00:00+00:00  2024-11-01 00:00:00+00:00
# 4081              0  2016-05-01 00:00:00+00:00  2018-05-01 00:00:00+00:00
# 4082              5  2018-05-16 00:00:00+00:00  2018-05-16 23:59:59+00:00
# 4083              4  2019-07-01 00:00:00+00:00  2024-11-01 00:00:00+00:00
# 4084              b  2016-04-01 00:00:00+00:00  2024-10-16 00:00:00+00:00
#
#       original_sample_id  label dataset
# 0                      1    110   HRVPP
# 1                      2    110   HRVPP
# 2                      3    110   HRVPP
# 3                      4    123   HRVPP
# 4                      5    110   HRVPP
# ...                  ...    ...     ...
# 4080                2726    123   HRVPP
# 4081                2727    110   HRVPP
# 4082                2727    211   HRVPP
# 4083                2727    123   HRVPP
# 4084                2728    123   HRVPP
#
# [4085 rows x 6 columns]

# %% [markdown]
# ## Windthrow samples
#
# Same format as HRVPP

# %%
wt = gpd.read_file("../data/windthrow_flags.geojson")
wt.columns
# Out:
# Index(['Id_poly', 'EventDate', 'StormName', 'EventType', 'Country', 'Area',
#        'Perimeter', 'Damage_deg', 'Methods', 'Dataprovid', 'Source', 'id',
#        'EventId', 'max_inscri', 'centroid', 'data_loc', 'confidence',
#        'comment', 'interpret1', 'segments', 'events', 'geometry'],
#       dtype='object')

# %%
flag_paths_wt = list(Path("../data/windthrow_flags").glob("*.json"))
raw_wt_labels = flags_to_label_df(flag_paths_wt).with_columns(
    pl.col.original_sample_id.cast(pl.Int32)
)
raw_wt_samples = flags_to_sample_df(flag_paths_wt).with_columns(
    pl.col.original_sample_id.cast(pl.Int32)
)
# Out:
# Missing Segment
# 11237
# {
#     "flags": {
#         "2016-12-02 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11241
# {
#     "flags": {
#         "2016-12-02 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11245
# {
#     "flags": {
#         "2016-12-05 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11260
# {
#     "flags": {
#         "2016-12-02 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "no wt",
#     "interpreter": "vij"
# }
# Missing Segment
# 11275
# {
#     "flags": {
#         "2016-12-02 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11311
# {
#     "flags": {
#         "2016-12-02 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "likely no wt",
#     "interpreter": "vij"
# }
# Missing Segment
# 11326
# {
#     "flags": {
#         "2016-12-02 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11354
# {
#     "flags": {
#         "2016-12-02 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11365
# {
#     "flags": {
#         "2016-11-12 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11371
# {
#     "flags": {
#         "2018-10-18 00:00:00.000000": "0",
#         "2018-10-26 00:00:00.000000": "7",
#         "2019-03-10 00:00:00.000000": "a"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11374
# {
#     "flags": {
#         "2016-12-02 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11389
# {
#     "flags": {
#         "2016-12-05 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11415
# {
#     "flags": {
#         "2017-07-15 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11476
# {
#     "flags": {
#         "2016-11-15 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11477
# {
#     "flags": {
#         "2016-11-12 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11488
# {
#     "flags": {
#         "2017-08-04 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11494
# {
#     "flags": {
#         "2016-12-05 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11553
# {
#     "flags": {
#         "2016-11-15 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11583
# {
#     "flags": {
#         "2016-11-15 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11593
# {
#     "flags": {
#         "2016-11-12 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11623
# {
#     "flags": {
#         "2017-07-15 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "definitely no wt",
#     "interpreter": "vij"
# }
# Missing Segment
# 11695
# {
#     "flags": {
#         "2017-07-15 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11746
# {
#     "flags": {
#         "2017-08-04 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "not this storm",
#     "interpreter": "vij"
# }
# Missing Segment
# 11818
# {
#     "flags": {
#         "2016-11-12 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11821
# {
#     "flags": {
#         "2016-11-12 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "wt closeby",
#     "interpreter": "vij"
# }
# Missing Segment
# 11841
# {
#     "flags": {
#         "2016-11-15 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11853
# {
#     "flags": {
#         "2016-11-12 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11885
# {
#     "flags": {
#         "2016-11-15 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11891
# {
#     "flags": {
#         "2016-12-05 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11900
# {
#     "flags": {
#         "2016-11-15 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11927
# {
#     "flags": {
#         "2016-11-12 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11965
# {
#     "flags": {
#         "2016-12-02 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11986
# {
#     "flags": {
#         "2016-11-12 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 11990
# {
#     "flags": {
#         "2016-11-12 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 12278
# {
#     "flags": {
#         "2016-12-25 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 1250
# {
#     "flags": {
#         "2016-11-28 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 13578
# {
#     "flags": {
#         "2016-11-14 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 13579
# {
#     "flags": {
#         "2020-01-08 00:00:00.000000": "0",
#         "2020-01-28 00:00:00.000000": "7"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 13616
# {
#     "flags": {
#         "2019-12-29 00:00:00.000000": "0",
#         "2020-01-28 00:00:00.000000": "7"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 13639
# {
#     "flags": {
#         "2016-12-24 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 1369
# {
#     "flags": {
#         "2016-11-28 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "only nearby",
#     "interpreter": "vij"
# }
# Missing Segment
# 13708
# {
#     "flags": {
#         "2020-01-08 00:00:00.000000": "0",
#         "2020-01-28 00:00:00.000000": "7"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 13770
# {
#     "flags": {
#         "2016-11-14 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 13845
# {
#     "flags": {
#         "2017-03-23 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 13854
# {
#     "flags": {
#         "2016-11-06 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "border, no wt",
#     "interpreter": "vij"
# }
# Missing Segment
# 13903
# {
#     "flags": {
#         "2017-03-23 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 1416
# {
#     "flags": {
#         "2016-11-28 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "no wt",
#     "interpreter": "vij"
# }
# Missing Segment
# 14238
# {
#     "flags": {
#         "2017-03-23 00:00:00.000000": "0",
#         "2023-07-28 00:00:00.000000": "5",
#         "2023-09-08 00:00:00.000000": "4",
#         "2024-10-20 00:00:00.000000": "4"
#     },
#     "confidence": "high",
#     "comment": "no wt",
#     "interpreter": "vij"
# }
# Missing Segment
# 14392
# {
#     "flags": {
#         "2017-01-25 00:00:00.000000": "0",
#         "2021-03-22 00:00:00.000000": "1",
#         "2023-06-20 00:00:00.000000": "1",
#         "2023-06-23 00:00:00.000000": "a",
#         "2024-07-07 00:00:00.000000": "4",
#         "2024-12-04 00:00:00.000000": "4"
#     },
#     "confidence": "medium",
#     "comment": "likely bark beetle",
#     "interpreter": "vij"
# }
# Missing Segment
# 14635
# {
#     "flags": {
#         "2016-12-26 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 14681
# {
#     "flags": {
#         "2023-08-07 00:00:00.000000": "0",
#         "2023-08-17 00:00:00.000000": "7"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 14915
# {
#     "flags": {
#         "2017-03-23 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 14995
# {
#     "flags": {
#         "2017-02-24 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 15063
# {
#     "flags": {
#         "2017-01-05 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 15285
# {
#     "flags": {
#         "2017-01-25 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 15705
# {
#     "flags": {
#         "2017-03-16 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 15972
# {
#     "flags": {
#         "2017-04-23 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 15976
# {
#     "flags": {
#         "2017-03-17 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 15979
# {
#     "flags": {
#         "2017-01-26 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "wrong timing",
#     "interpreter": "vij"
# }
# Missing Segment
# 15992
# {
#     "flags": {
#         "2016-11-17 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 16004
# {
#     "flags": {
#         "2016-11-17 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 16007
# {
#     "flags": {
#         "2017-04-29 00:00:00.000000": "0",
#         "2021-11-23 00:00:00.000000": "7",
#         "2022-02-27 00:00:00.000000": "a"
#     },
#     "confidence": "high",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 16022
# {
#     "flags": {
#         "2017-05-23 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 16024
# {
#     "flags": {
#         "2017-08-04 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "wt closeby",
#     "interpreter": "vij"
# }
# Missing Segment
# 16029
# {
#     "flags": {
#         "2017-08-04 00:00:00.000000": "0",
#         "2020-01-21 00:00:00.000000": "0",
#         "2020-02-15 00:00:00.000000": "7",
#         "2020-04-05 00:00:00.000000": "a",
#         "2024-12-30 00:00:00.000000": "4"
#     },
#     "confidence": "high",
#     "comment": "unclear salvage",
#     "interpreter": "vij"
# }
# Missing Segment
# 16034
# {
#     "flags": {
#         "2017-08-04 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 16036
# {
#     "flags": {
#         "2017-08-04 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 16041
# {
#     "flags": {
#         "2017-08-04 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 16051
# {
#     "flags": {
#         "2017-08-04 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 16053
# {
#     "flags": {
#         "2017-08-04 00:00:00.000000": "0",
#         "2020-02-15 00:00:00.000000": "7",
#         "2020-03-11 00:00:00.000000": "a",
#         "2020-07-04 00:00:00.000000": "4",
#         "2024-12-30 00:00:00.000000": "4"
#     },
#     "confidence": "medium",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 1610
# {
#     "flags": {
#         "2016-11-11 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "wt nearby",
#     "interpreter": "vij"
# }
# Missing Segment
# 1697
# {
#     "flags": {
#         "2016-11-11 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 1960
# {
#     "flags": {
#         "2016-11-11 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 2099
# {
#     "flags": {
#         "2016-11-11 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 4145
# {
#     "flags": {
#         "2016-11-15 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "wt closeby",
#     "interpreter": "vij"
# }
# Missing Segment
# 433
# {
#     "flags": {
#         "2016-12-29 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 4883
# {
#     "flags": {
#         "2016-11-01 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "border",
#     "interpreter": "vij"
# }
# Missing Segment
# 544
# {
#     "flags": {
#         "2016-11-12 00:00:00.000000": "0",
#         "2017-10-13 00:00:00.000000": "7",
#         "2018-04-06 00:00:00.000000": "a",
#         "2019-06-30 00:00:00.000000": "4",
#         "2024-12-25 00:00:00.000000": "4"
#     },
#     "confidence": "medium",
#     "comment": "border",
#     "interpreter": "vij"
# }
# Missing Segment
# 554
# {
#     "flags": {
#         "2016-11-22 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 559
# {
#     "flags": {
#         "2016-11-12 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 587
# {
#     "flags": {
#         "2016-11-02 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 6247
# {
#     "flags": {
#         "2016-12-31 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "no wt",
#     "interpreter": "vij"
# }
# Missing Segment
# 655
# {
#     "flags": {
#         "2016-11-12 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 6721
# {
#     "flags": {
#         "2017-08-13 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 673
# {
#     "flags": {
#         "2016-11-12 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "unclear - border",
#     "interpreter": "vij"
# }
# Missing Segment
# 733
# {
#     "flags": {
#         "2016-11-22 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "border",
#     "interpreter": "vij"
# }
# Missing Segment
# 7466
# {
#     "flags": {
#         "2016-12-31 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 7606
# {
#     "flags": {
#         "2016-11-14 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "no forest",
#     "interpreter": "vij"
# }
# Missing Segment
# 761
# {
#     "flags": {
#         "2016-11-01 00:00:00.000000": "0",
#         "2017-07-31 00:00:00.000000": "0",
#         "2017-08-03 00:00:00.000000": "3",
#         "2018-04-02 00:00:00.000000": "a",
#         "2018-04-07 00:00:00.000000": "3",
#         "2024-12-26 00:00:00.000000": "3"
#     },
#     "confidence": "high",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 773
# {
#     "flags": {
#         "2016-11-01 00:00:00.000000": "0",
#         "2017-07-31 00:00:00.000000": "0",
#         "2017-08-03 00:00:00.000000": "7",
#         "2018-03-08 00:00:00.000000": "a",
#         "2018-07-14 00:00:00.000000": "4"
#     },
#     "confidence": "high",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 787
# {
#     "flags": {
#         "2016-11-28 00:00:00.000000": "0",
#         "2017-07-31 00:00:00.000000": "0",
#         "2017-08-03 00:00:00.000000": "3",
#         "2018-04-02 00:00:00.000000": "a",
#         "2018-07-01 00:00:00.000000": "4",
#         "2024-12-16 00:00:00.000000": "4"
#     },
#     "confidence": "high",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 8025
# {
#     "flags": {
#         "2016-12-05 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 814
# {
#     "flags": {
#         "2016-11-01 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 844
# {
#     "flags": {
#         "2016-11-18 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": "unclear",
#     "interpreter": "vij"
# }
# Missing Segment
# 8635
# {
#     "flags": {
#         "2016-11-15 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }
# Missing Segment
# 8958
# {
#     "flags": {
#         "2016-11-15 00:00:00.000000": "0"
#     },
#     "confidence": "low",
#     "comment": null,
#     "interpreter": "vij"
# }

# %%
together_wt = (
    raw_wt_samples.filter(pl.col.confidence.ne("low"))
    .to_pandas()
    .merge(
        wt[["id", "Source", "EventId", "geometry"]],
        left_on="original_sample_id",
        right_on="id",
    )
)
together_wt
# Out:
#     confidence          comment interpreter  original_sample_id     id  \
# 0         high             None         vij               10017  10017
# 1         high             None         vij               10046  10046
# 2       medium           border         vij                1015   1015
# 3         high             None         vij                 102    102
# 4         high  unclear salvage         vij               10394  10394
# ..         ...              ...         ...                 ...    ...
# 289       high   no apparent wt         vij                  90     90
# 290       high  unclear salvage         vij                9503   9503
# 291       high             None         vij                9504   9504
# 292       high  unclear salvage         vij                9617   9617
# 293       high  unclear salvage         vij                9704   9704
#
#                                                 Source     EventId  \
# 0    http://foresta.sisef.org/contents/?id=efor3070...  IT20181028
# 1    http://foresta.sisef.org/contents/?id=efor3070...  IT20181028
# 2              https://www.mdpi.com/2072-4292/11/2/115  DE20171110
# 3    http://skogsdataportalen.skogsstyrelsen.se/Sko...  SE20181028
# 4    http://foresta.sisef.org/contents/?id=efor3070...  IT20181028
# ..                                                 ...         ...
# 289  http://skogsdataportalen.skogsstyrelsen.se/Sko...  SE20181028
# 290  http://foresta.sisef.org/contents/?id=efor3070...  IT20181028
# 291  http://foresta.sisef.org/contents/?id=efor3070...  IT20181028
# 292  http://foresta.sisef.org/contents/?id=efor3070...  IT20181028
# 293  http://foresta.sisef.org/contents/?id=efor3070...  IT20181028
#
#                       geometry
# 0    POINT (11.20557 45.98172)
# 1    POINT (11.25928 46.02815)
# 2    POINT (11.51864 53.19573)
# 3    POINT (13.16201 56.49697)
# 4    POINT (11.77777 46.19341)
# ..                         ...
# 289  POINT (11.49436 58.57324)
# 290  POINT (11.50066 46.09481)
# 291  POINT (11.52082 46.09586)
# 292  POINT (11.50803 46.15393)
# 293   POINT (11.80966 46.2084)
#
# [294 rows x 8 columns]

# %%
# Create the new GeoDataFrame for samples
# Initialize with None/default values where appropriate
samples_wt = (
    gpd.GeoDataFrame(
        {
            "original_sample_id": together_wt["id"],
            "interpreter": together_wt["interpreter"],
            "dataset": "Windthrow",
            "source": "FORWIND + Copernicus Emergency Service",
            "source_description": together_wt["Source"],
            "cluster_id": together_wt["EventId"],
            "cluster_description": "Id of the Event, given as ISO2 + Date of storm",
            "comment": together_wt["comment"],
            "confidence": together_wt["confidence"],
            "geometry": together_wt[
                "geometry"
            ],  # Geometry is already in shapely format from geopandas.read_file
        },
        crs=hrvpp.crs,  # Retain the original Coordinate Reference System
    )
    .astype(samples_schema.dtypes.drop(["sample_id", "s2_tile", "geometry"]))
    .sort_values("original_sample_id")
)

# %%
samples_wt
# Out:
#      original_sample_id interpreter    dataset  \
# 215                  60         vij  Windthrow
# 217                  61         vij  Windthrow
# 289                  90         vij  Windthrow
# 3                   102         vij  Windthrow
# 6                   105         vij  Windthrow
# ..                  ...         ...        ...
# 148               16066         vij  Windthrow
# 149               16067         vij  Windthrow
# 150               16070         vij  Windthrow
# 151               16071         vij  Windthrow
# 152               16076         vij  Windthrow
#
#                                      source  \
# 215  FORWIND + Copernicus Emergency Service
# 217  FORWIND + Copernicus Emergency Service
# 289  FORWIND + Copernicus Emergency Service
# 3    FORWIND + Copernicus Emergency Service
# 6    FORWIND + Copernicus Emergency Service
# ..                                      ...
# 148  FORWIND + Copernicus Emergency Service
# 149  FORWIND + Copernicus Emergency Service
# 150  FORWIND + Copernicus Emergency Service
# 151  FORWIND + Copernicus Emergency Service
# 152  FORWIND + Copernicus Emergency Service
#
#                                     source_description  cluster_id  \
# 215  http://skogsdataportalen.skogsstyrelsen.se/Sko...  SE20181028
# 217  http://skogsdataportalen.skogsstyrelsen.se/Sko...  SE20181028
# 289  http://skogsdataportalen.skogsstyrelsen.se/Sko...  SE20181028
# 3    http://skogsdataportalen.skogsstyrelsen.se/Sko...  SE20181028
# 6    http://skogsdataportalen.skogsstyrelsen.se/Sko...  SE20181028
# ..                                                 ...         ...
# 148  https://mapping.emergency.copernicus.eu/activa...  SI20200205
# 149  https://mapping.emergency.copernicus.eu/activa...  SI20200205
# 150  https://mapping.emergency.copernicus.eu/activa...  SI20200205
# 151  https://mapping.emergency.copernicus.eu/activa...  SI20200205
# 152  https://mapping.emergency.copernicus.eu/activa...  SI20200205
#
#                                 cluster_description          comment  \
# 215  Id of the Event, given as ISO2 + Date of storm   no apparent wt
# 217  Id of the Event, given as ISO2 + Date of storm   no apparent wt
# 289  Id of the Event, given as ISO2 + Date of storm   no apparent wt
# 3    Id of the Event, given as ISO2 + Date of storm             <NA>
# 6    Id of the Event, given as ISO2 + Date of storm             <NA>
# ..                                              ...              ...
# 148  Id of the Event, given as ISO2 + Date of storm             <NA>
# 149  Id of the Event, given as ISO2 + Date of storm  unclear salvage
# 150  Id of the Event, given as ISO2 + Date of storm             <NA>
# 151  Id of the Event, given as ISO2 + Date of storm  unclear salvage
# 152  Id of the Event, given as ISO2 + Date of storm             <NA>
#
#     confidence                   geometry
# 215       high  POINT (14.00079 58.07212)
# 217       high  POINT (13.99821 58.07167)
# 289       high  POINT (11.49436 58.57324)
# 3         high  POINT (13.16201 56.49697)
# 6         high  POINT (14.13445 56.28274)
# ..         ...                        ...
# 148       high   POINT (14.39175 46.2299)
# 149       high    POINT (14.4004 46.2291)
# 150       high  POINT (14.39046 46.24575)
# 151       high   POINT (14.39247 46.2441)
# 152       high   POINT (14.4381 46.25011)
#
# [294 rows x 10 columns]

# %%
# bring them to start end format as done for the hrvpp calibration set
labels_wt = (
    raw_wt_labels.with_columns(
        pl.col.original_label.replace_strict(hrvpp_label_mapping).alias("label"),
        dataset=pl.lit("Windthrow"),
    )
    .to_pandas()
    .astype(labels_schema.dtypes.drop("sample_id"))
)
labels_wt
# Out:
#      original_label                      start                        end  \
# 0                 0  2016-11-28 00:00:00+00:00  2021-06-03 00:00:00+00:00
# 1                 5  2021-06-05 00:00:00+00:00  2021-06-05 23:59:59+00:00
# 2                 4  2022-08-12 00:00:00+00:00  2024-11-21 00:00:00+00:00
# 3                 0  2016-11-15 00:00:00+00:00  2018-10-24 00:00:00+00:00
# 4                 7  2018-11-15 00:00:00+00:00  2018-11-15 23:59:59+00:00
# ...             ...                        ...                        ...
# 1034              4  2019-09-16 00:00:00+00:00  2024-12-28 00:00:00+00:00
# 1035              0  2016-11-15 00:00:00+00:00  2018-10-26 00:00:00+00:00
# 1036              7  2018-10-31 00:00:00+00:00  2018-10-31 23:59:59+00:00
# 1037              a  2021-05-28 00:00:00+00:00  2021-05-28 23:59:59+00:00
# 1038              4  2022-06-17 00:00:00+00:00  2024-11-23 00:00:00+00:00
#
#       original_sample_id  label    dataset
# 0                    100    110  Windthrow
# 1                    100    211  Windthrow
# 2                    100    123  Windthrow
# 3                  10017    110  Windthrow
# 4                  10017    243  Windthrow
# ...                  ...    ...        ...
# 1034                9617    123  Windthrow
# 1035                9704    110  Windthrow
# 1036                9704    243  Windthrow
# 1037                9704    220  Windthrow
# 1038                9704    123  Windthrow
#
# [1039 rows x 6 columns]

# %% [markdown]
# # Concatenate all data
#
# In this step we also remove all samples with confidence `low`

# %%
samples = pd.concat(
    [samples_schema, samples_evo, samples_hrvpp, samples_wt]
).reset_index(drop=True)
# set new unique sample_id
samples["sample_id"] = pd.Series(range(len(samples)), dtype="uint16[pyarrow]")
samples["confidence"] = samples["confidence"].str.lower()
samples = samples.query("confidence!='low'")
samples
# Out:
#       sample_id  original_sample_id interpreter    dataset  \
# 0             0                   0         vij    Evoland
# 1             1                   1         vij    Evoland
# 2             2                   2         vij    Evoland
# 3             3                   3         vij    Evoland
# 4             4                   4         vij    Evoland
# ...         ...                 ...         ...        ...
# 3818       3818               16066         vij  Windthrow
# 3819       3819               16067         vij  Windthrow
# 3820       3820               16070         vij  Windthrow
# 3821       3821               16071         vij  Windthrow
# 3822       3822               16076         vij  Windthrow
#
#                                       source  \
# 0                                      EFFIS
# 1                                      EFFIS
# 2                                      EFFIS
# 3                                      EFFIS
# 4                                      EFFIS
# ...                                      ...
# 3818  FORWIND + Copernicus Emergency Service
# 3819  FORWIND + Copernicus Emergency Service
# 3820  FORWIND + Copernicus Emergency Service
# 3821  FORWIND + Copernicus Emergency Service
# 3822  FORWIND + Copernicus Emergency Service
#
#                                      source_description s2_tile  cluster_id  \
# 0     Evoland Project, EFFIS Source of Wildfire Poly...   30SUF         0.0
# 1     Evoland Project, EFFIS Source of Wildfire Poly...   30SUF         1.0
# 2     Evoland Project, EFFIS Source of Wildfire Poly...   30SUF         2.0
# 3     Evoland Project, EFFIS Source of Wildfire Poly...   30SUF         3.0
# 4     Evoland Project, EFFIS Source of Wildfire Poly...   30SUF         5.0
# ...                                                 ...     ...         ...
# 3818  https://mapping.emergency.copernicus.eu/activa...    <NA>  SI20200205
# 3819  https://mapping.emergency.copernicus.eu/activa...    <NA>  SI20200205
# 3820  https://mapping.emergency.copernicus.eu/activa...    <NA>  SI20200205
# 3821  https://mapping.emergency.copernicus.eu/activa...    <NA>  SI20200205
# 3822  https://mapping.emergency.copernicus.eu/activa...    <NA>  SI20200205
#
#                                  cluster_description  \
# 0                                    Damage polygons
# 1                                    Damage polygons
# 2                                    Damage polygons
# 3                                    Damage polygons
# 4                                    Damage polygons
# ...                                              ...
# 3818  Id of the Event, given as ISO2 + Date of storm
# 3819  Id of the Event, given as ISO2 + Date of storm
# 3820  Id of the Event, given as ISO2 + Date of storm
# 3821  Id of the Event, given as ISO2 + Date of storm
# 3822  Id of the Event, given as ISO2 + Date of storm
#
#                                comment confidence                   geometry
# 0     border, thinning, then clear cut       high  POINT (-4.12212 36.74179)
# 1            unclear progression, edge     medium  POINT (-4.12161 36.74231)
# 2                           plantation       high   POINT (-4.1192 36.74203)
# 3                           plantation       high  POINT (-4.12845 36.75831)
# 4                            clear cut       high  POINT (-4.12816 36.75908)
# ...                                ...        ...                        ...
# 3818                              <NA>       high   POINT (14.39175 46.2299)
# 3819                   unclear salvage       high    POINT (14.4004 46.2291)
# 3820                              <NA>       high  POINT (14.39046 46.24575)
# 3821                   unclear salvage       high   POINT (14.39247 46.2441)
# 3822                              <NA>       high   POINT (14.4381 46.25011)
#
# [3823 rows x 12 columns]

# %%
labels = pd.concat([labels_schema, labels_evo, labels_hrvpp, labels_wt])
# set new sample_ids to labels
labels = labels.drop("sample_id", axis=1).merge(
    samples[["original_sample_id", "dataset", "sample_id"]],
    on=["original_sample_id", "dataset"],
    how="inner",
)

labels
# Out:
#       original_sample_id    dataset  label original_label  \
# 0                      0    Evoland    110              0
# 1                      0    Evoland    212              6
# 2                      0    Evoland    211              5
# 3                      1    Evoland    110              0
# 4                      1    Evoland    211              5
# ...                  ...        ...    ...            ...
# 7908                9617  Windthrow    123              4
# 7909                9704  Windthrow    110              0
# 7910                9704  Windthrow    243              7
# 7911                9704  Windthrow    220              a
# 7912                9704  Windthrow    123              4
#
#                           start                        end  sample_id
# 0     2016-11-10 00:00:00+00:00  2022-03-09 00:00:00+00:00          0
# 1     2022-04-08 00:00:00+00:00  2022-04-08 23:59:59+00:00          0
# 2     2024-04-02 00:00:00+00:00  2024-04-02 23:59:59+00:00          0
# 3     2016-11-10 00:00:00+00:00  2023-05-03 00:00:00+00:00          1
# 4     2023-06-22 00:00:00+00:00  2023-06-22 23:59:59+00:00          1
# ...                         ...                        ...        ...
# 7908  2019-09-16 00:00:00+00:00  2024-12-28 00:00:00+00:00       3686
# 7909  2016-11-15 00:00:00+00:00  2018-10-26 00:00:00+00:00       3687
# 7910  2018-10-31 00:00:00+00:00  2018-10-31 23:59:59+00:00       3687
# 7911  2021-05-28 00:00:00+00:00  2021-05-28 23:59:59+00:00       3687
# 7912  2022-06-17 00:00:00+00:00  2024-11-23 00:00:00+00:00       3687
#
# [7913 rows x 7 columns]

# %%
# Throw out d class in original_label (data artifact only relevant to our specific data source, might get irrelevant later etc)
labels = labels.query("original_label!='d'")
# Sort by sample_id and start date to ensure chronological order
labels = labels.sort_values(["sample_id", "start"]).reset_index(drop=True)

# Group by sample_id and shift the start column to get the next start date
labels["start_next_label"] = labels.groupby("sample_id")["start"].shift(-1)
labels
# Out:
#       original_sample_id    dataset  label original_label  \
# 0                      0    Evoland    110              0
# 1                      0    Evoland    212              6
# 2                      0    Evoland    211              5
# 3                      1    Evoland    110              0
# 4                      1    Evoland    211              5
# ...                  ...        ...    ...            ...
# 7908               16071  Windthrow    243              7
# 7909               16071  Windthrow    120              3
# 7910               16076  Windthrow    110              0
# 7911               16076  Windthrow    243              7
# 7912               16076  Windthrow    123              4
#
#                           start                        end  sample_id  \
# 0     2016-11-10 00:00:00+00:00  2022-03-09 00:00:00+00:00          0
# 1     2022-04-08 00:00:00+00:00  2022-04-08 23:59:59+00:00          0
# 2     2024-04-02 00:00:00+00:00  2024-04-02 23:59:59+00:00          0
# 3     2016-11-10 00:00:00+00:00  2023-05-03 00:00:00+00:00          1
# 4     2023-06-22 00:00:00+00:00  2023-06-22 23:59:59+00:00          1
# ...                         ...                        ...        ...
# 7908  2020-03-11 00:00:00+00:00  2020-03-11 23:59:59+00:00       3821
# 7909  2020-03-16 00:00:00+00:00  2024-12-30 00:00:00+00:00       3821
# 7910  2017-08-04 00:00:00+00:00  2020-01-21 00:00:00+00:00       3822
# 7911  2020-03-11 00:00:00+00:00  2020-03-11 23:59:59+00:00       3822
# 7912  2020-06-29 00:00:00+00:00  2024-12-30 00:00:00+00:00       3822
#
#                start_next_label
# 0     2022-04-08 00:00:00+00:00
# 1     2024-04-02 00:00:00+00:00
# 2                          <NA>
# 3     2023-06-22 00:00:00+00:00
# 4                          <NA>
# ...                         ...
# 7908  2020-03-16 00:00:00+00:00
# 7909                       <NA>
# 7910  2020-03-11 00:00:00+00:00
# 7911  2020-06-29 00:00:00+00:00
# 7912                       <NA>
#
# [7913 rows x 8 columns]

# %% [markdown]
# ## Assign appropriate salvage class
#
# If the salvage class can be narrowed (biotic/abiotic disturbance previous in the segmentation), then we do this here

# %%
# change label 220 within a unique sample_id to:
# -  221 if sample_id group has label starting with 23 (abiotic)
# -  222 if sample_id group has label starting with 24 (biotic)
# -  Leave as 220 if original_sample_id has neither 23 or 24
def determine_new_label(group):
    labels = group["label"].astype(str)
    if not (labels == "220").any():
        return labels
    # only run through rest of logic if there is a 220 class
    has_23 = labels.str.startswith("23").any()
    has_24 = labels.str.startswith("24").any()

    # Create new labels based on conditions
    new_labels = labels.copy()
    mask_220 = labels.str.startswith("220")

    if has_23 and has_24:
        pass
    elif has_23:
        new_labels.loc[mask_220] = "221"
    elif has_24:
        new_labels.loc[mask_220] = "222"

    return new_labels


labels["label"] = (
    labels.groupby("sample_id")
    .apply(determine_new_label, include_groups=False)
    .reset_index(level=0, drop=True)
)
labels["label"] = labels["label"].astype("uint16[pyarrow]")

# %%
labels.dtypes
# Out:
# original_sample_id                   int64[pyarrow]
# dataset                             string[pyarrow]
# label                               uint16[pyarrow]
# original_label                      string[pyarrow]
# start                 timestamp[s, tz=UTC][pyarrow]
# end                   timestamp[s, tz=UTC][pyarrow]
# sample_id                           uint16[pyarrow]
# start_next_label      timestamp[s, tz=UTC][pyarrow]
# dtype: object

# %% [markdown]
# # Write data

# %%
samples.to_parquet("../data/samples.parquet")
labels.to_parquet("../data/labels.parquet")

# %%
# write a csv map from dataset, original sample id to new sample id to track changes with git
samples[["sample_id", "original_sample_id", "dataset"]].to_csv(
    "../data/id_mapping.csv", index=False
)
